# %% [markdown]
# # תחקור פר שאלה

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#all
all_data = pd.read_excel("Data2/קובץ מתכלל כללי.xlsx")

#sviot ratzon
all_data[all_data.columns[41]] = all_data[all_data.columns[41]].apply(lambda x: "כן" if x==0 else "לא")

#heil avir & yom alef
yom_alef_avir = all_data[(all_data["חיל אוויר"]=="כן")&(all_data["יום בשבוע"]=="ראשון")]
#heil avir & yom bet
yom_bet_avir = all_data[(all_data["חיל אוויר"]=="כן")&(all_data["יום בשבוע"]=="שני")]

#else & yom alef
yom_alef_else = all_data[(all_data["חיל אוויר"]=="לא")&(all_data["יום בשבוע"]=="ראשון")]

#else & yom bet
yom_bet_else = all_data[(all_data["חיל אוויר"]=="לא")&(all_data["יום בשבוע"]=="שני")]



def four_plot_nominal(column_number = None, plot_color = 'teal', text_color = 'cyan'):
    """
    four graph for numinal objects
    """
    plt.style.use('ggplot')
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
    fig.set_figheight(10)
    fig.set_figwidth(10)
    fig.suptitle(all_data.columns[column_number][::-1], size = 20)
    ax1.tick_params(axis='both', which='major', labelsize=12)
    #יום א יחידות צהל ללא חיל אויר
    labels = [label[::-1] for label in yom_alef_else[yom_alef_else.columns[column_number]].value_counts().index.tolist()]
    ax1.bar(labels,yom_alef_else[all_data.columns[column_number]].value_counts(), color = plot_color)
    ax1.set_title("יחידות צהל ללא חיל אויר יום א"[::-1])
    
    for j in range(len(yom_alef_else[yom_alef_else.columns[column_number]].value_counts())):
        txt = f"{round(yom_alef_else[yom_alef_else.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax1.text(j, yom_alef_else[yom_alef_else.columns[column_number]].value_counts()[j]+5,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

    #יום ב יחידות צהל ללא חיל אויר
    labels = [label[::-1] for label in yom_bet_else[yom_bet_else.columns[column_number]].value_counts().index.tolist()]
    ax2.bar(labels,yom_bet_else[yom_bet_else.columns[column_number]].value_counts(), color = plot_color)
    ax2.set_title("יחידות צהל ללא חיל אויר יום ב"[::-1])
    ax2.tick_params(axis='both', which='major', labelsize=12)
    for j in range(len(yom_bet_else[yom_bet_else.columns[column_number]].value_counts())):
        txt = f"{round(yom_bet_else[yom_bet_else.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax2.text(j, yom_bet_else[yom_bet_else.columns[column_number]].value_counts()[j],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

    #חיל אוויר יום א
    labels = [label[::-1] for label in yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts().index.tolist()]
    ax3.bar(labels,yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts(), color = plot_color)
    ax3.set_title("חיל אויר יום א"[::-1])
    ax3.tick_params(axis='both', which='major', labelsize=12)
    for j in range(len(yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts())):
        txt = f"{round(yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax3.text(j, yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts()[j],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

    #חיל אוויר יום ב
    labels = [label[::-1] for label in yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts().index.tolist()]
    ax4.bar(labels,yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts(), color = plot_color)
    ax4.set_title("חיל אויר יום ב"[::-1])
    ax4.tick_params(axis='both', which='major', labelsize=12)
    for j in range(len(yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts())):
        txt = f"{round(yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax4.text(j, yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts()[j]-1,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))
    
def all_plot_nominal(column_number = None, plot_color = 'teal', text_color = 'cyan'):
    plt.figure(figsize = (8,5))
    labels = [label[::-1] for label in all_data[all_data.columns[column_number]].value_counts().index.tolist()]
    plt.bar(labels,all_data[all_data.columns[column_number]].value_counts(), color = plot_color)
    for j in range(len(all_data[all_data.columns[column_number]].value_counts())):
        txt = f"{round(all_data[all_data.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        plt.text(j, all_data[all_data.columns[column_number]].value_counts()[j]+5,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
    plt.title(all_data.columns[column_number][::-1], size = 20)
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.show()
    
def four_plot_nominal2(column_number = None, n= 10,height = 10, width = 10, plot_color = 'teal', text_color = 'cyan'):
    """
    four graph for numinal objects
    """
    plt.style.use('ggplot')
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
    fig.set_figheight(height)
    fig.set_figwidth(width)
    fig.suptitle(all_data.columns[column_number][::-1], size = 20)

    #יום א יחידות צהל ללא חיל אויר
    labels = [label[::-1] for label in yom_alef_else[yom_alef_else.columns[column_number]].value_counts().index.tolist()[:n]]
    ax1.bar(labels,yom_alef_else[all_data.columns[column_number]].value_counts()[:n], color = plot_color)
    ax1.set_xticklabels(labels,rotation=45)
    ax1.set_title("יחידות צהל ללא חיל אויר יום א"[::-1])
    ax1.tick_params(axis='both', which='major', labelsize=12)
    for j in range(len(yom_alef_else[yom_alef_else.columns[column_number]].value_counts()[:n])):
        txt = f"{round(yom_alef_else[yom_alef_else.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax1.text(j, yom_alef_else[yom_alef_else.columns[column_number]].value_counts()[j]+1,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

    #יום ב יחידות צהל ללא חיל אויר
    labels = [label[::-1] for label in yom_bet_else[yom_bet_else.columns[column_number]].value_counts().index.tolist()[:n]]
    ax2.bar(labels,yom_bet_else[yom_bet_else.columns[column_number]].value_counts()[:n], color = plot_color)
    ax2.set_xticklabels(labels,rotation=45)
    ax2.set_title("יחידות צהל ללא חיל אויר יום ב"[::-1])
    ax2.tick_params(axis='both', which='major', labelsize=12)
    for j in range(len(yom_bet_else[yom_bet_else.columns[column_number]].value_counts()[:n])):
        txt = f"{round(yom_bet_else[yom_bet_else.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax2.text(j, yom_bet_else[yom_bet_else.columns[column_number]].value_counts()[j],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

    #חיל אוויר יום א
    labels = [label[::-1] for label in yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts().index.tolist()[:n]]
    ax3.bar(labels,yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts()[:n], color = plot_color)
    ax3.set_xticklabels(labels,rotation=45)
    ax3.set_title("חיל אויר יום א"[::-1])
    ax3.tick_params(axis='both', which='major', labelsize=12)
    for j in range(len(yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts()[:n])):
        txt = f"{round(yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax3.text(j, yom_alef_avir[yom_alef_avir.columns[column_number]].value_counts()[j],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

    #חיל אוויר יום ב
    labels = [label[::-1] for label in yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts().index.tolist()[:n]]
    ax4.bar(labels,yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts()[:n], color = plot_color)
    ax4.set_xticklabels(labels,rotation=45)
    ax4.set_title("חיל אויר יום ב"[::-1])
    ax4.tick_params(axis='both', which='major', labelsize=12)
    for j in range(len(yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts()[:n])):
        txt = f"{round(yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        ax4.text(j, yom_bet_avir[yom_bet_avir.columns[column_number]].value_counts()[j],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))
    
def all_plot_nominal2(column_number = None,n = 10, plot_color = 'teal', text_color = 'cyan'):
    plt.figure(figsize = (20,5))
    labels = [label[::-1] for label in all_data[all_data.columns[column_number]].value_counts().index.tolist()[:n]]
    plt.bar(labels,all_data[all_data.columns[column_number]].value_counts()[:n], color = plot_color)
    
    for j in range(len(all_data[all_data.columns[column_number]].value_counts()[:n])):
        txt = f"{round(all_data[all_data.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        plt.text(j, all_data[all_data.columns[column_number]].value_counts()[j]+1,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.title(all_data.columns[column_number][::-1], size = 20)
    plt.show()
#for ax in fig.get_axes():
    #ax.label_outer()
    
def all_plot_nominal3(column_number = None,n = 10, plot_color = 'teal', text_color = 'cyan'):
    plt.figure(figsize = (20,5))
    labels = [label[::-1] for label in all_data[all_data.columns[column_number]].value_counts().index.tolist()[:n]]
    plt.bar(labels,all_data[all_data.columns[column_number]].value_counts()[:n], color = plot_color)

    for j in range(len(all_data[all_data.columns[column_number]].value_counts()[:n])):
        txt = f"{round(all_data[all_data.columns[column_number]].value_counts(normalize = True)[j]*100,2)}%"
        plt.text(j, all_data[all_data.columns[column_number]].value_counts()[j]+1,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor=text_color,alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
    plt.title(all_data.columns[column_number][::-1])
    plt.xticks(rotation=90,size = 14)
    plt.show()

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 45 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   חותמת זמן                                                                           1960 non-null   datetime64[ns]
#  1   מהו מגדרך?                                                                          1960 non-null   object
#  2   מהו סוג שירותך?                                                                     1960 non-null   object
#  3   מהו מקום המגורים שלך?                                                               1960 non-null   object
#  4   מהו הבסיס אליו אתה מגיע?                                                            1960 non-null   object
# ...

# %% [markdown]
# # 1. מהו מגדרך?

# %%
four_plot_nominal(1,plot_color = 'teal',text_color = 'aliceblue')

# %%
all_plot_nominal(1,plot_color = 'teal',text_color = 'aliceblue')

# %% [markdown]
# # 2. מהו סוג שירותך?

# %%
four_plot_nominal(2,plot_color = 'orange',text_color = 'wheat')

# %%
all_plot_nominal(2,plot_color = 'orange',text_color = 'wheat')

# %% [markdown]
# # 3. מהו מקום המגורים שלך?

# %%
four_plot_nominal2(column_number = 3, n= 10,height = 15, width = 20, plot_color = 'rosybrown', text_color = 'snow')
# Out:
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:95: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:105: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:115: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:125: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels,rotation=45)

# %%
all_plot_nominal2(column_number = 3, n= 10,plot_color = 'rosybrown', text_color = 'snow')

# %% [markdown]
# # 4. מהו הבסיס אליו אתה מגיע?

# %%
four_plot_nominal2(column_number = 4, n= 10,height = 20, width = 20, plot_color = 'crimson', text_color = 'lavenderblush')
# Out:
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:95: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:105: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:115: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:125: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels,rotation=45)

# %%
all_plot_nominal2(column_number = 4, n= 10, plot_color = 'crimson', text_color = 'lavenderblush')

# %% [markdown]
# # 5. מהו מתחם ההסעה בו אתה נמצא כעת?

# %%
four_plot_nominal2(column_number = 5, n= 10,height = 20, width = 20, plot_color = 'yellowgreen', text_color = 'honeydew')
# Out:
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:95: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:105: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:115: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:125: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels,rotation=45)

# %%
all_plot_nominal3(column_number = 5, n= 10, plot_color = 'yellowgreen', text_color = 'honeydew')

# %% [markdown]
# # 6. מהי תדירות יציאותיך מהבסיס?

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.set_figheight(10)
fig.set_figwidth(20)
fig.suptitle(all_data.columns[6][::-1], size = 20)
ax1.tick_params(axis='both', which='major', labelsize=12)
#יום א יחידות צהל ללא חיל אויר
labels = ['אחת לשבועיים',
 'אחת לשבוע',
 'יומיות',
 'אחת לשלושה שבועות ומעלה']
labels = [label[::-1] for label in labels]
ax1.bar(labels,yom_alef_else[all_data.columns[6]].value_counts(), color = 'beige')
ax1.set_title("יחידות צהל ללא חיל אויר יום א"[::-1])

for j in range(len(yom_alef_else[yom_alef_else.columns[6]].value_counts())):
    txt = f"{round(yom_alef_else[yom_alef_else.columns[6]].value_counts(normalize = True)[j]*100,2)}%"
    ax1.text(j, yom_alef_else[yom_alef_else.columns[6]].value_counts()[j]+5,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

#יום ב יחידות צהל ללא חיל אויר
labels = ['אחת לשבוע',
 'אחת לשבועיים',
 'יומיות',
 'אחת לשלושה שבועות ומעלה']
labels = [label[::-1] for label in labels]
ax2.bar(labels,yom_bet_else[yom_bet_else.columns[6]].value_counts(), color = 'beige')
ax2.set_title("יחידות צהל ללא חיל אויר יום ב"[::-1])
ax2.tick_params(axis='both', which='major', labelsize=12)
for j in range(len(yom_bet_else[yom_bet_else.columns[6]].value_counts())):
    txt = f"{round(yom_bet_else[yom_bet_else.columns[6]].value_counts(normalize = True)[j]*100,2)}%"
    ax2.text(j, yom_bet_else[yom_bet_else.columns[6]].value_counts()[j],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

#חיל אוויר יום א
#labels = [label[::-1] for label in labels]
ax3.bar(labels,yom_alef_avir[yom_alef_avir.columns[6]].value_counts(), color = 'beige')
ax3.set_title("חיל אויר יום א"[::-1])
ax3.tick_params(axis='both', which='major', labelsize=12)
for j in range(len(yom_alef_avir[yom_alef_avir.columns[6]].value_counts())):
    txt = f"{round(yom_alef_avir[yom_alef_avir.columns[6]].value_counts(normalize = True)[j]*100,2)}%"
    ax3.text(j, yom_alef_avir[yom_alef_avir.columns[6]].value_counts()[j],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

#חיל אוויר יום ב
labels = ['אחת לשבוע',
 'אחת לשבועיים',
 'אחת לשלושה שבועות ומעלה']
labels = [label[::-1] for label in labels]
ax4.bar(labels[:3],yom_bet_avir[yom_bet_avir.columns[6]].value_counts(), color = 'beige')
ax4.set_title("חיל אויר יום ב"[::-1])
ax4.tick_params(axis='both', which='major', labelsize=12)
for j in range(len(yom_bet_avir[yom_bet_avir.columns[6]].value_counts())):
    txt = f"{round(yom_bet_avir[yom_bet_avir.columns[6]].value_counts(normalize = True)[j]*100,2)}%"
    ax4.text(j, yom_bet_avir[yom_bet_avir.columns[6]].value_counts()[j]-1,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.2'))

# %%
plt.figure(figsize = (8,5))
labels = ['אחת לשבוע',
 'אחת לשבועיים',
 'יומיות',
 'אחת לשלושה שבועות ומעלה']
labels = [label[::-1] for label in labels]
plt.bar(labels,all_data[all_data.columns[6]].value_counts(), color = 'beige')
for j in range(len(all_data[all_data.columns[6]].value_counts())):
    txt = f"{round(all_data[all_data.columns[6]].value_counts(normalize = True)[j]*100,2)}%"
    plt.text(j, all_data[all_data.columns[6]].value_counts()[j]+5,txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(all_data.columns[6][::-1], size = 20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 7. מדוע הגעת לתחנה הזו היום?

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
l = [a.split(",") for a in all_data.iloc[:,7].dropna()]
flatten_list = list(chain.from_iterable(l))
Data = dict(Counter(flatten_list))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)[:15]}
#מהירה
Data[list(Data.keys())[1]] = Data[list(Data.keys())[1]] + Data[list(Data.keys())[6]]
#נוחה
Data[list(Data.keys())[2]] = Data[list(Data.keys())[2]] + Data[list(Data.keys())[4]]
#קרובה
Data[list(Data.keys())[3]] = Data[list(Data.keys())[3]] + Data[list(Data.keys())[5]]
#איני מכיר
Data[list(Data.keys())[7]] = Data[list(Data.keys())[7]] + Data[list(Data.keys())[8]]

Data = {k: Data[k] for k in list(Data.keys())[0:1] + list(Data.keys())[1:3]+ list(Data.keys())[3:4] + list(Data.keys())[7:9]}

# %%
plt.figure(figsize  = (12,8) )
plt.bar([a[::-1] for a in Data.keys()],Data.values(), color = 'yellowgreen')
sm = sum(Data.values())
for i in range(len(list(Data.keys()))):
    txt = f"{round(list(Data.values())[i]/sm*100,2)}%"
    plt.text(i, list(Data.values())[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[7][24::-1]}", size=  20)
plt.xticks(rotation = 90,size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 8. באיזו שעה הוגדר לך להגיע לבסיס היום?

# %% [markdown]
# # 9. באיזו שעה אתה מעריך שתגיע לבסיס היום?

# %% [markdown]
# # 10. האם לרוב אתה מגיע בזמן לבסיס?

# %%
all_data[all_data.columns[10]].value_counts()
plt.figure(figsize = (10,6))
plt.bar(all_data[all_data.columns[10]].value_counts().index,all_data[all_data.columns[10]].value_counts(), color = 'slateblue')
for i in all_data[all_data.columns[10]].value_counts().index:
    txt = f"{round(all_data[all_data.columns[10]].value_counts(normalize = True)*100,2)[i]}%"
    plt.text(i, all_data[all_data.columns[10]].value_counts()[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[10][::-1]}", size=  20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 11. מניסיונך, באיזו מידה מתחם ההסעה בו אתה נמצא כעת עמוס בדרך כלל?

# %%
all_data[all_data.columns[11]].value_counts()
plt.figure(figsize = (10,6))
plt.bar(all_data[all_data.columns[11]].value_counts().index,all_data[all_data.columns[11]].value_counts(), color = 'slateblue')
for i in all_data[all_data.columns[11]].value_counts().index:
    txt = f"{round(all_data[all_data.columns[11]].value_counts(normalize = True)*100,2)[i]}%"
    plt.text(i, all_data[all_data.columns[11]].value_counts()[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[11][::-1]}", size=  20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 12. באופן כללי, האם אתה עובר תדרוך יציאה לפני יציאתך הביתה?

# %%
all_plot_nominal(12,plot_color = 'khaki',text_color = 'cornsilk')

# %%
four_plot_nominal(12,plot_color = 'khaki',text_color = 'cornsilk')

# %% [markdown]
# # 13. באופן כללי האם אתה מקבל הנחיות הגעה לבסיס?  (בתדרוך היציאה/ בכלל)

# %%
all_plot_nominal(13,plot_color = 'firebrick',text_color = 'cornsilk')

# %%
four_plot_nominal(13,plot_color = 'firebrick',text_color = 'cornsilk')

# %% [markdown]
# # 14.באיזו מידה הנך שבע רצון מדרך ההגעה שלך לבסיס?

# %%
all_data[all_data.columns[14]].value_counts()
plt.figure(figsize = (10,6))
plt.bar(all_data[all_data.columns[14]].value_counts().index,all_data[all_data.columns[14]].value_counts(), color = 'slateblue')
for i in all_data[all_data.columns[14]].value_counts().index:
    txt = f"{round(all_data[all_data.columns[14]].value_counts(normalize = True)*100,2)[i]}%"
    plt.text(i, all_data[all_data.columns[14]].value_counts()[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[14][::-1]}", size=  20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 15.באילו סוגי אמצעי תחבורה אתה משתמש לרוב בדרכך לבסיס? (ניתן לסמן יותר מתשובה אחת)

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
l = [a.split(",") for a in all_data.iloc[:,15].dropna()]
flatten_list = list(chain.from_iterable(l))
Data = dict(Counter(flatten_list))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)[:15]}


#תחצ אוטובוסים
Data[list(Data.keys())[0]] = Data[list(Data.keys())[1]] + Data[list(Data.keys())[6]]

#תחצ רכבת
Data[list(Data.keys())[1]] = Data[list(Data.keys())[1]] + Data[list(Data.keys())[2]]

#הסעה צבאית ללא שאטל
Data[list(Data.keys())[3]] = Data[list(Data.keys())[3]] + Data[list(Data.keys())[-4]]

#הסעה צבאית יחידה
Data[list(Data.keys())[5]] = Data[list(Data.keys())[5]] + Data[list(Data.keys())[9]]

#שאטל ליחידה
Data[list(Data.keys())[7]] = Data[list(Data.keys())[7]] + Data[list(Data.keys())[8]]

#שאטל הזמנת חייל
Data[list(Data.keys())[10]] = Data[list(Data.keys())[10]] + Data[list(Data.keys())[12]]


Data = {k: Data[k] for k in list(Data.keys())[0:2] + list(Data.keys())[3:6]+ list(Data.keys())[7:8] + list(Data.keys())[10:11] + list(Data.keys())[13:15]}
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)}

# %%
plt.figure(figsize  = (12,8) )
plt.bar([a[::-1] for a in Data.keys()],Data.values(), color = 'salmon')
sm = sum(Data.values())
for i in range(len(list(Data.keys()))):
    txt = f"{round(list(Data.values())[i]/sm*100,2)}%"
    plt.text(i, list(Data.values())[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[15][50::-1]}", size=  20)
plt.xticks(rotation = 90,size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 16.באילו סוגי אמצעי תחבורה אתה מעדיף בדרכך לבסיס? (ניתן לסמן יותר מתשובה אחת)

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
l = [a.split(",") for a in all_data.iloc[:,16].dropna()]
flatten_list = list(chain.from_iterable(l))
Data = dict(Counter(flatten_list))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)[:100]}
Data
# Out:
# {'הסעות צבאיות שהוזמנו על ידי היחידה': 468,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 387,
#  'הכי נוחים (כיסאות': 249,
#  ' מזגן': 249,
#  ' שקעים...)': 249,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 234,
#  'תחבורה ציבורית - רכבת': 218,
#  ' הכי מהירים': 144,
#  ' תחבורה ציבורית - רכבת': 138,
#  ' תחבורה ציבורית - אוטובוס': 117,
#  'תחבורה ציבורית - אוטובוס': 110,
#  ' הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 103,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 98,
#  'אין לי העדפה': 61,
#  'הכי מהירים': 58,
#  ' הכי קרובים למקום מגוריי': 55,
#  ' שעות יציאתם הכי נוחות': 40,
#  ' אינם עמוסים': 39,
#  'הכי קרובים למקום מגוריי': 29,
#  ' חבריי נוסעים באמצעים אלו': 19,
#  'אינם עמוסים': 14,
#  'אחר': 13,
#  ' אין לי העדפה': 10,
#  ' אחר': 9,
#  'שעות יציאתם הכי נוחות': 8,
#  'כי אין ברירה': 2,
#  'אין העדפה': 2,
#  'לא רלוונטי': 2,
#  'חבריי נוסעים באמצעים אלו': 2,
#  'בדיקה': 2,
#  'אוטו זה הכי נוח': 1,
#  ' אין תחלופה של קווים': 1,
# ...

# %% [markdown]
# # 17.בדרכך לבסיס, מדוע אתה מעדיף את אמצעי התחבורה האלו? (ניתן לסמן יותר מתשובה אחת)

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
l = [a.split(",") for a in all_data.iloc[:,17].dropna()]
flatten_list = list(chain.from_iterable(l))
Data = dict(Counter(flatten_list))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)[:100]}
Data
# Out:
# {'הכי נוחים (כיסאות': 1293,
#  ' מזגן': 1293,
#  ' שקעים...)': 1293,
#  ' הכי מהירים': 725,
#  ' הכי קרובים למקום מגוריי': 533,
#  ' שעות יציאתם הכי נוחות': 425,
#  ' אינם עמוסים': 402,
#  'הכי מהירים': 331,
#  ' חבריי נוסעים באמצעים אלו': 283,
#  'הכי קרובים למקום מגוריי': 159,
#  'אינם עמוסים': 62,
#  'שעות יציאתם הכי נוחות': 48,
#  'חבריי נוסעים באמצעים אלו': 23,
#  'כי אין ברירה': 2,
#  'אין העדפה': 2,
#  'לא רלוונטי': 2,
#  'בדיקה': 2,
#  ' מסודרים': 1,
#  'אוטו זה הכי נוח': 1,
#  'אלה האמצעים היחידים העומדים לרשותי': 1,
#  'רק דרך זה אפשר לצאת מהבסיס': 1,
#  'לא תמיד יש תחבצ לדרום ובכלל בימי שישי לכן ההסעות של הבסיס עוזרות אחרת אנחנו נתקעים בבסיס': 1,
#  ' אין דרך אחרת להגיע לבסיס': 1,
#  'אין לי ברירה ': 1,
#  'אין משהו אחר': 1,
#  'כי אין לי רכב פרטי': 1,
#  ' אין תחלופה של קווים': 1,
#  ' בשאטל אפשר להירדם בראש שקט וגם להגיע בלי להסתבך': 1,
#  ' ואם יש פקקים או איחורים לא אשמתי': 1,
#  ' אין לי אופציה אחרת להגיע': 1,
#  ' הם לא מסובכים': 1,
#  ' או מסבכים ': 1,
# ...

# %% [markdown]
# # 18.כמה אמצעי תחבורה אתה מחליף בדרכך לבסיס?

# %%
all_plot_nominal3(18)

# %%
four_plot_nominal2(18,5,20,20)
# Out:
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:95: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:105: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:115: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:125: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels,rotation=45)

# %% [markdown]
# # 19.באיזו מידה הנך שבע רצון מדרך החזרה שלך מהבסיס?

# %%
all_data[all_data.columns[19]].value_counts()
plt.figure(figsize = (10,6))
plt.bar(all_data[all_data.columns[19]].value_counts().index,all_data[all_data.columns[19]].value_counts(), color = 'violet')
for i in all_data[all_data.columns[19]].value_counts().index:
    txt = f"{round(all_data[all_data.columns[19]].value_counts(normalize = True)*100,2)[i]}%"
    plt.text(i, all_data[all_data.columns[19]].value_counts()[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[14][::-1]}", size=  20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 20.באילו סוגי אמצעי תחבורה אתה משתמש לרוב בחזרתך מהבסיס? (ניתן לסמן יותר מתשובה אחת)

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
l = [a.split(",") for a in all_data.iloc[:,20].dropna()]
flatten_list = list(chain.from_iterable(l))
Data = dict(Counter(flatten_list))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)[:100]}
Data
# Out:
# {' תחבורה ציבורית - אוטובוס': 819,
#  ' תחבורה ציבורית - רכבת': 423,
#  'הסעות צבאיות שהוזמנו על ידי היחידה': 389,
#  'תחבורה ציבורית - רכבת': 350,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 318,
#  'רכב פרטי': 316,
#  'תחבורה ציבורית - אוטובוס': 222,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 164,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 153,
#  ' הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 116,
#  ' הסעות צבאיות שהוזמנו על ידי היחידה': 100,
#  ' הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 72,
#  ' הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 62,
#  'טרמפים': 40,
#  ' אחר': 21,
#  ' טרמפים': 13,
#  'אחר': 8}

# %% [markdown]
# # 21.באילו סוגי אמצעי תחבורה אתה מעדיף בחזרתך מהבסיס? (ניתן לסמן יותר מתשובה אחת)

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
l = [a.split(",") for a in all_data.iloc[:,21].dropna()]
flatten_list = list(chain.from_iterable(l))
Data = dict(Counter(flatten_list))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)[:100]}
Data
# Out:
# {'הסעות צבאיות שהוזמנו על ידי היחידה': 614,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 377,
#  'תחבורה ציבורית - רכבת': 284,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 234,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 205,
#  ' תחבורה ציבורית - אוטובוס': 204,
#  ' תחבורה ציבורית - רכבת': 191,
#  'תחבורה ציבורית - אוטובוס': 156,
#  ' הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 143,
#  'אין לי העדפה': 63,
#  'אחר': 27,
#  ' אחר': 8,
#  ' אין לי העדפה': 2}

# %% [markdown]
# # 22.באילו סוגי אמצעי תחבורה אתה מעדיף בחזרתך מהבסיס? (ניתן לסמן יותר מתשובה אחת)

# %%
all_plot_nominal3(22,5)

# %%
four_plot_nominal2(22,5,20,20)
# Out:
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:95: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:105: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:115: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:125: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels,rotation=45)

# %% [markdown]
# # שאלות 23-26

# %%
for i in range(23,26):
    all_plot_nominal(i)
    four_plot_nominal(i)

# %% [markdown]
# # 28. באיזו מידה הנך שבע רצון מהשימוש באפליקציית "שאטל"?

# %%
all_data[all_data.columns[28]].value_counts()
plt.figure(figsize = (10,6))
plt.bar(all_data[all_data.columns[28]].value_counts().index,all_data[all_data.columns[28]].value_counts(), color = 'slateblue')
for i in all_data[all_data.columns[28]].value_counts().index:
    txt = f"{round(all_data[all_data.columns[28]].value_counts(normalize = True)*100,2)[i]}%"
    plt.text(i, all_data[all_data.columns[28]].value_counts()[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[28][::-1]}", size=  20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 29. באיזו תדירות אתה משתמש באפליקצייה?

# %%
plt.figure(figsize = (10,6))
plt.bar(all_data[all_data.columns[29]].value_counts().index,all_data[all_data.columns[29]].value_counts(), color = 'slateblue')
for i in all_data[all_data.columns[29]].value_counts().index:
    txt = f"{round(all_data[all_data.columns[29]].value_counts(normalize = True)*100,2)[i]}%"
    plt.text(i, all_data[all_data.columns[29]].value_counts()[i],txt,size=12,style = 'italic',color = "black",bbox=dict(facecolor='ivory',alpha=0.8, edgecolor='white', boxstyle='Sawtooth,pad=0.5'))
plt.title(f"{all_data.columns[29][::-1]}", size=  20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# # 30. במידה ואינך משתמש באפליקציית "שאטל" בתדירות גבוהה, מהי הסיבה לכך?

# %%
all_data[all_data.columns[30]].value_counts()[:10]
# Out:
# לא רלוונטי                                                          432
# השאטל יוצא בשעה שאינה נוחה עבורי                                     56
# לא פתחו עבורי אפשרות להזמין שאטל                                     55
# אין עבורי מקום בשאטל (גם אם הזמנתי)                                  21
# האפליקתייה לא עובדת לי                                                1
# משתמשים בה רק ביציאה הביתה                                            1
# מזמינים מהבסיס ללא שאטל                                               1
# האפליקציה מציגה רק מבחר קטן של תחנות ולא לא בהתאם לגדודים השונים      1
# כושלת, לא מספיק מקומות, לא עובדת                                      1
# אני משתמשת                                                            1
# Name: במידה ואינך משתמש באפליקציית "שאטל" בתדירות גבוהה, מהי הסיבה לכך?, dtype: int64

# %% [markdown]
# # 31.בהזמנת השאטל מהאפליקצייה, האם הוא מגיע קרוב למקום מגוריך?

# %%
all_plot_nominal(31)

# %%
four_plot_nominal2(31,3,20,20)
# Out:
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:95: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:105: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:115: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:125: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels,rotation=45)

# %% [markdown]
# # 32.כמה אמצעי תחבורה אתה מחליף בדרכך לשאטל? (כלל קווי האוטובוס, רכבות ועוד)

# %%
all_plot_nominal3(32)

# %%
four_plot_nominal2(32,5,20,20)
# Out:
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:95: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:105: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:115: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(labels,rotation=45)
# C:\Users\97254\AppData\Local\Temp/ipykernel_23840/575437297.py:125: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels,rotation=45)

# %% [markdown]
# # 35.ברקוד או מתשאלים

# %%
all_plot_nominal(35)

# %%
four_plot_nominal(35)

# %% [markdown]
# # 36.יום בשבוע

# %%
all_plot_nominal(36)

# %% [markdown]
# # 37.בחזרתך מהבסיס מדוע אתה מעדיף את אמצעי תחבורה אלו

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
l = [a.split(",") for a in all_data.iloc[:,37].dropna()]
flatten_list = list(chain.from_iterable(l))
Data = dict(Counter(flatten_list))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)[:10]}
Data
# Out:
# {'הכי נוחים (כיסאות': 971,
#  ' מזגן': 971,
#  ' שקעים...)': 971,
#  ' הכי מהירים': 618,
#  ' הכי קרובים למקום מגוריי': 451,
#  'הכי מהירים': 371,
#  ' אינם עמוסים': 336,
#  ' שעות יציאתם הכי נוחות': 319,
#  ' חבריי נוסעים באמצעים אלו': 225,
#  'הכי קרובים למקום מגוריי': 111}

# %% [markdown]
# # 38. חלוקת זמן להערכת הגעה

# %%
all_plot_nominal(38)

# %%
four_plot_nominal(38)

# %% [markdown]
# # 39. חלוקת זמן למקום הגעה מוגדר

# %%
all_plot_nominal(39)

# %%
four_plot_nominal(39)

# %% [markdown]
# # 40. חיל אויר

# %%
all_plot_nominal(40)

# %% [markdown]
# # 41. התאמת שביעות רצון חזרה/הגעה

# %%
all_plot_nominal(41)

# %%
four_plot_nominal(41)

# %% [markdown]
# # 42. השוואת שביעות רצון חזרה והגעה

# %%
all_plot_nominal(42)

# %%
four_plot_nominal(42)

# %% [markdown]
# # 43. השוואת שביעות רצון חזרה והגעה

# %%
all_plot_nominal(43)

# %%
four_plot_nominal(43)

# %% [markdown]
# # 44.איזה שעה יצאת הבוקר ממקום מגוריך?
