# %% [markdown]
# # 23.12.21 ניתוח

# %%
import pandas as pd
#all
all_data = pd.read_excel("Data2/קובץ מתכלל כללי.xlsx")

#sviot ratzon
all_data[all_data.columns[41]] = all_data[all_data.columns[41]].apply(lambda x: "כן" if x==0 else "לא")

#heil avir & yom alef
yom_alef_avir = all_data[(all_data["חיל אוויר"]=="כן")&(all_data["יום בשבוע"]=="ראשון")]
#heil avir & yom bet
yom_bet_avir = all_data[(all_data["חיל אוויר"]=="כן")&(all_data["יום בשבוע"]=="שני")]

#else & yom alef
yom_alef_else = all_data[(all_data["חיל אוויר"]=="לא")&(all_data["יום בשבוע"]=="ראשון")]

#else & yom bet
yom_bet_else = all_data[(all_data["חיל אוויר"]=="לא")&(all_data["יום בשבוע"]=="שני")]

#colors
my_colors = ["orange","yellow","red","lime","pink",
         "mediumpurple","skyblue","cornflowerblue","gray","gainsboro",
         "gold","turquoise","chocolate","forestgreen","orchid"]

# %% [markdown]
# # מגדר

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#define data
df =all_data[all_data.columns[1]].value_counts()
labels = df.index
sizes = df.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df.values/sum(df.values)))

colors = dict(zip(labels,my_colors[10:13]))

#create pie chart
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels = [label if label_dict[label]>0.015  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
plt.title(all_data.columns[1][::-1], size = 30)
#plt.legend(labels,fontsize = 14)
plt.show()

# %% [markdown]
# # עומס במתחם ההיסעים

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#define data
df =all_data[all_data.columns[2]].value_counts()
labels = df.index
sizes = df.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df.values/sum(df.values)))

colors = dict(zip(labels,my_colors[:4]))

#create pie chart
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels = [label if label_dict[label]>0.015  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
plt.title(all_data.columns[2][::-1], size = 30)
#plt.legend(labels,fontsize = 14)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#define data
df =all_data[all_data.columns[6]].value_counts()
labels = df.index
sizes = df.values

labels= [label[::-1] for label in ['אחת לשבוע','אחת לשבועיים','יומיות','אחת לשלושה שבועות ומעלה']]
label_dict = dict(zip(labels,df.values/sum(df.values)))

colors = dict(zip(labels,my_colors[:4]))

#create pie chart
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels = [label if label_dict[label]>0.015  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
plt.title(all_data.columns[6][::-1], size = 30)
#plt.legend(labels,fontsize = 14)
plt.show()

# %% [markdown]
# # באר שבע ללא באר שבע

# %%
df = all_data[(all_data[all_data.columns[5]].isin(["יס פלנט באר שבע","תחנה מרכזית באר שבע"]))&(all_data[all_data.columns[48]]!="באר שבע")]
df1 = df[df.columns[48]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[1:8]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels = [label if label_dict[label]>0.03  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'תחנות ההסעה ב"ש ללא אזור ב"ש'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(["יס פלנט באר שבע","תחנה מרכזית באר שבע"]))&(all_data[all_data.columns[48]]!="באר שבע")]


df = df[df.columns[55]].value_counts().sort_index()

labels = df.index
sizes = df.values

labels= [label[::-1] for label in labels]
colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(["יס פלנט באר שבע","תחנה מרכזית באר שבע"]))&(all_data[all_data.columns[48]]!="באר שבע")]


df = df[df.columns[53]].value_counts().sort_index()
df.index = ["80 רמגוא"] + df.index.tolist()[1:]
labels = df.index
sizes = df.values

labels= [labels[0]] + [label[::-1] for label in labels[1:]]
colors = dict(zip(labels,my_colors + ["teal","tomato","cornsilk"]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=None,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'תחנות ב"ש ללא אזור ב"ש: פילוח יחידות'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(["יס פלנט באר שבע","תחנה מרכזית באר שבע"]))&(all_data[all_data.columns[48]]!="באר שבע")&(all_data[all_data.columns[53]]=='יחידות חה"א')][all_data.columns[55]].value_counts().sort_index()
labels = df.index
sizes = df.values

labels= [label[::-1] for label in labels]
colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'חיל אויר - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(["יס פלנט באר שבע","תחנה מרכזית באר שבע"]))&(all_data[all_data.columns[48]]!="באר שבע")&(all_data[all_data.columns[53]]=='ז"י')][all_data.columns[55]].value_counts().sort_index()
labels = df.index
sizes = df.values

labels= [label[::-1] for label in labels]
colors = dict(zip(labels,my_colors[-3:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'זרוע יבשה - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(["יס פלנט באר שבע","תחנה מרכזית באר שבע"]))&(all_data[all_data.columns[48]]=="מרכז")]
df1 = df[df.columns[53]].value_counts()[:15]

labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
labels[-3] = "80 רמגוא"
colors = dict(zip(labels,my_colors))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels[:8] + [""]*5,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})

r = 'התפלגות יחידות מגיעים לחניון בבאר שבע וגרים במרכז: '
plt.title(r[::-1], size = 30)
plt.ylabel(" ")
plt.show()

# %%
df1 = df[df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})

plt.title(r[::-1], size = 30)
plt.legend(labels,fontsize = 14)
plt.ylabel(" ")
plt.show()

# %% [markdown]
# # חניוני סביבת תל אביב ללא גוש דן

# %%
henionim_telaviv = ['בית דני','אצטדיון רמת גן','חניון ארלוזורוב תל אביב','תחנה מרכזית תל אביב', 'הדר יוסף תל אביב', 'רידינג תל אביב']

df = all_data[(all_data[all_data.columns[5]].isin(henionim_telaviv))&(all_data[all_data.columns[52]]!="גוש דן")]
df1 = df[df.columns[48]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[1:8]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels = [label if label_dict[label]>0.015  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'תחנות ההסעה תל אביב והסביבה ללא אזור גוש דן'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
henionim_telaviv = ['בית דני','אצטדיון רמת גן','חניון ארלוזורוב תל אביב','תחנה מרכזית תל אביב', 'הדר יוסף תל אביב', 'רידינג תל אביב']

df = all_data[(all_data[all_data.columns[5]].isin(henionim_telaviv))&(all_data[all_data.columns[52]]!="גוש דן")]
df1 = df[df.columns[53]].value_counts()[:15].sort_index()

labels = df1.index.tolist()
sizes = df1.values

labels= [label[::-1] for label in labels]
labels[1] = "80 רמגוא"
labels[2] = '91 רמגוא'

colors = dict(zip(labels,my_colors + my_colors[:7]))

label_dict = dict(zip(labels,df1.values/sum(df1.values)))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})
title_text = 'תחנות ההסעה תל אביב והסביבה ללא אזור גוש דן: פילוח יחידות'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,loc = "upper left",fontsize = 14)
plt.show()

# %%
df1 = df[df.columns[55]].value_counts().sort_index()

labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})

title_text = 'סיבת ההגעה לתחנה\nתחנות ההסעה תל אביב והסביבה ללא אזור גוש דן: '
plt.title(title_text[::-1], size=  30)
plt.legend(labels,fontsize = 14)
plt.ylabel(" ")
plt.show()

# %%
df1 = df[df[df.columns[53]]=='יחידות חה"א'][df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
colors = dict(zip(labels,my_colors[-2:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = 'חיל אויר - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df1 = df[df[df.columns[53]]=='ז"י'][df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = 'זרוע יבשה - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(henionim_telaviv))&(all_data[all_data.columns[52]]!="גוש דן")&(all_data[all_data.columns[48]]=="מרכז")]
df1 = df[df.columns[53]].value_counts()

labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
#labels[-3] = "80 רמגוא"
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors + my_colors))
plt.figure(figsize  = (15,15))
plt.pie(sizes,labels=[label if label_dict[label]>0.05  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 5 else '',textprops={'fontsize': 25})

r = 'התפלגות יחידות מגיעים לחניון באזור תל אביב וגרים במרכז מחוץ לגוש דן: '
plt.title(r[::-1], size = 30)
plt.legend([label if label_dict[label]<0.05  else "" for label in labels],fontsize = 14)
plt.ylabel(" ")
plt.show()

# %%
df1 = df[df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = 'התפלגות סיבות הגעה מגיעים לחניון באזור תל אביב וגרים במרכז מחוץ לגוש דן: '
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %% [markdown]
# # ירושלים

# %%
henionim_jas = ['תחנה מרכזית ירושלים', 'טדי ירושלים'] 

df = all_data[(all_data[all_data.columns[5]].isin(henionim_jas))&(all_data[all_data.columns[48]]!="ירושלים")]
df1 = df[df.columns[48]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[2:4]+my_colors[5:8]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels = [label if label_dict[label]>0.015  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'תחנות ההסעה ירושלים ללא אזור ירושלים'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df1 = df[df.columns[53]].value_counts().sort_index()

labels = df1.index.tolist()
sizes = df1.values

labels= [label[::-1] for label in labels]
labels[1] = "80 רמגוא"
labels[0] = '91 רמגוא'

colors = dict(zip(labels,my_colors + my_colors[:7]))

label_dict = dict(zip(labels,df1.values/sum(df1.values)))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})
title_text = 'תחנות ההסעה ירושלים ללא אזור ירושלים: פילוח יחידות'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,loc = "upper left",fontsize = 14)
plt.show()

# %%
df1 = df[df.columns[55]].value_counts().sort_index()

labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})

title_text = 'סיבת ההגעה לתחנה\nתחנות ההסעה ירושלים ללא אזור ירושלים: '
plt.title(title_text[::-1], size=  30)
plt.legend(labels,fontsize = 14)
plt.ylabel(" ")
plt.show()

# %%
df1 = df[df[df.columns[53]]=='יחידות חה"א'][df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
colors = dict(zip(labels,my_colors[-2:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = 'חיל אויר - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df1 = df[df[df.columns[53]]=='ז"י'][df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-2:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = 'זרוע יבשה - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(henionim_jas))&(all_data[all_data.columns[52]]!="ירושלים")&(all_data[all_data.columns[48]]=="מרכז")]
df1 = df[df.columns[53]].value_counts()

labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
#labels[-3] = "80 רמגוא"
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors + my_colors))
plt.figure(figsize  = (15,15))
plt.pie(sizes,labels=[label if label_dict[label]>0.05  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 5 else '',textprops={'fontsize': 25})

r = 'התפלגות יחידות מגיעים לחניון בירושלים וגרים במרכז: '
plt.title(r[::-1], size = 30)
#plt.legend([label if label_dict[label]<0.05  else "" for label in labels],fontsize = 14)
plt.ylabel(" ")
plt.show()

# %%
df1 = df[df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-3:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
r = 'התפלגות סיבת הגעה לחניון בירושלים וגרים במרכז: '
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %% [markdown]
# # חיפה והסביבה

# %%
henionim_haifa = ['חניון חוף זמיר חיפה', 'חוף הכרמל חיפה','לב המפרץ חיפה']

df = all_data[(all_data[all_data.columns[5]].isin(henionim_haifa))&(all_data[all_data.columns[48]]!="חיפה")]
df1 = df[df.columns[48]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[:2] + my_colors[4:8]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels = [label if label_dict[label]>0.03  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3 else '',textprops={'fontsize': 25})
title_text = 'תחנות ההסעה חיפה ללא אזור חיפה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df1 = df[df.columns[53]].value_counts().sort_index()

labels = df1.index.tolist()
sizes = df1.values

labels= [label[::-1] for label in labels]
labels[2] = "80 רמגוא"
labels[1] = '91 רמגוא'

colors = dict(zip(labels,my_colors + my_colors[:7]))

label_dict = dict(zip(labels,df1.values/sum(df1.values)))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})
title_text = 'תחנות ההסעה חיפה ללא אזור חיפה: פילוח יחידות'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,loc = "upper right",fontsize = 14)
plt.show()

# %%
df1 = df[df.columns[55]].value_counts().sort_index()

labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-4:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})

title_text = 'סיבת ההגעה לתחנה\nתחנות ההסעה חיפה ללא אזור חיפה: '
plt.title(title_text[::-1], size=  30)
plt.legend(labels,fontsize = 14)
plt.ylabel(" ")
plt.show()

# %%
df1 = df[df[df.columns[53]]=='יחידות חה"א'][df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
colors = dict(zip(labels,my_colors[-3:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=labels,colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = 'חיל אויר - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df1 = df[df[df.columns[53]]=='ז"י'][df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-2:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = 'זרוע יבשה - סיבת ההגעה לתחנת הסעה'
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(henionim_haifa))&(all_data[all_data.columns[48]]=="צפון מערבי")]
df1 = df[df.columns[53]].value_counts()

labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
labels[-1] = "91 רמגוא"
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors + my_colors))
plt.figure(figsize  = (15,15))
plt.pie(sizes,labels=[label if label_dict[label]>0.05  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 5 else '',textprops={'fontsize': 25})

r = 'התפלגות יחידות מגיעים לחניון בחיפה וגרים במרחב הצפון מערבי: '
plt.title(r[::-1], size = 30)
plt.legend([label if label_dict[label]<0.05  else "" for label in labels],fontsize = 14)
plt.ylabel(" ")
plt.show()

# %%
df1 = df[df.columns[55]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[-3:]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
r = 'התפלגות סיבת הגעה לחניון בחיפה וגרים במרחב צפון מערבי: '
plt.title(title_text[::-1], size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %% [markdown]
# # הקשר בין מספר ההחלפות, סוג אמצעי התחבורה, מקום המגורים ותחנת ההסעה

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
df = all_data[all_data[all_data.columns[18]].isin(['אין לי החלפות - 0','החלפה אחת - 1'])]
l = [a.split(",") for a in df.iloc[:,15].dropna()]
l = list(chain.from_iterable(l))
#[x+1 if x >= 45 else x+5 for x in l]
l =  [a[1:] if a.startswith(" ") else a for a in l]  
l =  [a[:-1] if a.endswith(" ") else a for a in l]  
#set(l)
Data = dict(Counter(l))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)}
Data
# Out:
# {'תחבורה ציבורית - אוטובוס': 216,
#  'תחבורה ציבורית - רכבת': 163,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 156,
#  'הסעות צבאיות שהוזמנו על ידי היחידה': 141,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 115,
#  'רכב פרטי': 113,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 54,
#  'טרמפים': 11,
#  'אחר': 6}

# %%
import numpy as np
labels = ["תחבורה ציבורית - אוטובוס","תחבורה ציבורית - רכבת","היסעים שכורים","רכב פרטי","טרמפים","אחר"]
sizes = [216,163,466,113,11,6]

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,np.array(sizes)/sum(sizes)))

colors = dict(zip(labels,my_colors[:6]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels], autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 1.5 else '',textprops={'fontsize': 25})
title_text = "החלפת 0 או 1 אמצעי תחבורה"
plt.title(f'{all_data.columns[15][50::-1]} :{title_text[::-1]}', size=  30)
plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df1 = df[df.columns[5]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors + my_colors[:2]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.05  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 5 else '',textprops={'fontsize': 25})

plt.title(f'{all_data.columns[5][50::-1]} :{title_text[::-1]}', size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
#plt.legend(labels ,fontsize = 12)
plt.show()

# %%
df1 = df[df.columns[48]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[:8]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.05  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 5 else '',textprops={'fontsize': 25})

plt.title(f'{all_data.columns[3][::-1]} :{title_text[::-1]}', size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels ,fontsize = 12)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[18]].isin(['אין לי החלפות - 0','החלפה אחת - 1'])]

# %%
from random import randint as ri
from itertools import chain
from collections import Counter
df = all_data[all_data[all_data.columns[18]].isin(['ארבע החלפות ומעלה - 4+','שלוש החלפות - 3'])]
l = [a.split(",") for a in df.iloc[:,15].dropna()]
l = list(chain.from_iterable(l))
#[x+1 if x >= 45 else x+5 for x in l]
l =  [a[1:] if a.startswith(" ") else a for a in l]  
l =  [a[:-1] if a.endswith(" ") else a for a in l]  
#set(l)
Data = dict(Counter(l))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)}
Data
# Out:
# {'תחבורה ציבורית - אוטובוס': 395,
#  'תחבורה ציבורית - רכבת': 325,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 104,
#  'הסעות צבאיות שהוזמנו על ידי היחידה': 102,
#  'רכב פרטי': 84,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 67,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 40,
#  'טרמפים': 22,
#  'אחר': 12}

# %%
import numpy as np
labels = ["תחבורה ציבורית - אוטובוס","תחבורה ציבורית - רכבת","היסעים שכורים","רכב פרטי","טרמפים","אחר"]
sizes = [395,325,313,84,22,12]

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,np.array(sizes)/sum(sizes)))

colors = dict(zip(labels,my_colors[:6]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels], autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})
title_text = "החלפת 3 או 4 אמצעי תחבורה"
plt.title(f'{all_data.columns[15][50::-1]} :{title_text[::-1]}', size=  30)
plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,loc = 'upper left',fontsize = 14)
plt.show()

# %%
df1 = df[df.columns[5]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors + my_colors[:2]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.05  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 5 else '',textprops={'fontsize': 25})

plt.title(f'{all_data.columns[5][50::-1]} :{title_text[::-1]}', size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
#plt.legend(labels ,fontsize = 12)
plt.show()

# %%
df1 = df[df.columns[48]].value_counts().sort_index()
labels = df1.index
sizes = df1.values

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,df1.values/sum(df1.values)))

colors = dict(zip(labels,my_colors[:8]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.05  else "" for label in labels],colors = [colors[p] for p in labels],autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 5 else '',textprops={'fontsize': 25})

plt.title(f'{all_data.columns[3][::-1]} :{title_text[::-1]}', size=  30)
#plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels ,fontsize = 12)
plt.show()

# %% [markdown]
# # שימוש והעדפה אמצעי תחבורה (33+34)

# %%
from random import randint as ri
from itertools import chain
from collections import Counter

l = [a.split(",") for a in all_data.iloc[:,15].dropna()]
l = list(chain.from_iterable(l))
#[x+1 if x >= 45 else x+5 for x in l]
l =  [a[1:] if a.startswith(" ") else a for a in l]  
l =  [a[:-1] if a.endswith(" ") else a for a in l]  
#set(l)
Data = dict(Counter(l))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)}
Data
# Out:
# {'תחבורה ציבורית - אוטובוס': 916,
#  'תחבורה ציבורית - רכבת': 753,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 370,
#  'הסעות צבאיות שהוזמנו על ידי היחידה': 349,
#  'רכב פרטי': 280,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 230,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 130,
#  'טרמפים': 42,
#  'אחר': 26}

# %%
labels = ["תחבורה ציבורית - אוטובוס","תחבורה ציבורית - רכבת","היסעים שכורים","רכב פרטי","טרמפים","אחר"]
sizes = [916,753,1079,280,42,26]

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,np.array(sizes)/sum(sizes)))

colors = dict(zip(labels,my_colors[:6]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels], autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})
title_text = "החלפת 3 או 4 אמצעי תחבורה"
plt.title(f'{all_data.columns[15][50::-1]}', size=  30)
plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,loc = 'upper left',fontsize = 14)
plt.show()

# %%
from random import randint as ri
from itertools import chain
from collections import Counter

l = [a.split(",") for a in all_data.iloc[:,16].dropna()]
l = list(chain.from_iterable(l))
#[x+1 if x >= 45 else x+5 for x in l]
l =  [a[1:] if a.startswith(" ") else a for a in l]  
l =  [a[:-1] if a.endswith(" ") else a for a in l]  
#set(l)
Data = dict(Counter(l))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)}
Data
# Out:
# {'הסעות צבאיות שהוזמנו על ידי היחידה': 468,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 387,
#  'תחבורה ציבורית - רכבת': 356,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 234,
#  'תחבורה ציבורית - אוטובוס': 227,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 201,
#  'אין לי העדפה': 71,
#  'אחר': 22,
#  'הכי מהירים': 2}

# %%
labels = ["תחבורה ציבורית - אוטובוס","תחבורה ציבורית - רכבת","היסעים שכורים","אין לי העדפה","הכי מהירים","אחר"]
sizes = [227,356,1290,71,2,22]

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,np.array(sizes)/sum(sizes)))

colors = dict(zip(labels,my_colors[:6]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels], autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})
title_text = "החלפת 3 או 4 אמצעי תחבורה"
plt.title(f'{all_data.columns[16][45::-1]}', size=  30)
plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,loc = 'upper left',fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(["יס פלנט באר שבע","תחנה מרכזית באר שבע"]))&(all_data[all_data.columns[48]]!="באר שבע")]
l = [a.split(",") for a in df.iloc[:,16].dropna()]
l = list(chain.from_iterable(l))
#[x+1 if x >= 45 else x+5 for x in l]
l =  [a[1:] if a.startswith(" ") else a for a in l]  
l =  [a[:-1] if a.endswith(" ") else a for a in l]  
#set(l)
Data = dict(Counter(l))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)}
Data
# Out:
# {'הסעות צבאיות שהוזמנו על ידי היחידה': 128,
#  'תחבורה ציבורית - רכבת': 99,
#  'תחבורה ציבורית - אוטובוס': 88,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 61,
#  'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 46,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 41,
#  'אין לי העדפה': 19,
#  'אחר': 5}

# %%
labels = ["תחבורה ציבורית - אוטובוס","תחבורה ציבורית - רכבת","היסעים שכורים","אין לי העדפה","אחר"]
sizes = [88,99,276,19,5]

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,np.array(sizes)/sum(sizes)))

colors = dict(zip(labels,my_colors[:5]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.035  else "" for label in labels],colors = [colors[p] for p in labels], autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3.5 else '',textprops={'fontsize': 25})
title_text = "חניוני באר שבע ללא באר שבע"
plt.title(f'{all_data.columns[16][45::-1]} :{title_text[::-1]}', size=  30)
plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,fontsize = 14)
plt.show()

# %%
df = all_data[(all_data[all_data.columns[5]].isin(henionim_telaviv))&(all_data[all_data.columns[52]]!="גוש דן")]
l = [a.split(",") for a in df.iloc[:,16].dropna()]
l = list(chain.from_iterable(l))
#[x+1 if x >= 45 else x+5 for x in l]
l =  [a[1:] if a.startswith(" ") else a for a in l]  
l =  [a[:-1] if a.endswith(" ") else a for a in l]  
#set(l)
Data = dict(Counter(l))
Data = {k: Data[k] for k in sorted(Data, key=Data.get, reverse=True)}
Data
# Out:
# {'הסעה צבאית שהוזמנה ע"י היחידה ללא שימוש באפליקציית "שאט"ל"': 121,
#  'הסעות צבאיות שהוזמנו על ידי היחידה': 66,
#  'תחבורה ציבורית - רכבת': 57,
#  'הסעה צבאית שהוזמנה ליחידה על ידי אפליקציית "שאט"ל"': 40,
#  'תחבורה ציבורית - אוטובוס': 25,
#  'הסעות צבאיות בהזמנת החייל (אפליקציית "שאטל")': 23,
#  'אין לי העדפה': 12,
#  'אחר': 3}

# %%
labels = ["תחבורה ציבורית - אוטובוס","תחבורה ציבורית - רכבת","היסעים שכורים","אין לי העדפה","אחר"]
sizes = [57,25,250,12,3]

labels= [label[::-1] for label in labels]
label_dict = dict(zip(labels,np.array(sizes)/sum(sizes)))

colors = dict(zip(labels,my_colors[:5]))
plt.figure(figsize  = (15,15))
plt.pie(sizes, labels=[label if label_dict[label]>0.03  else "" for label in labels],colors = [colors[p] for p in labels], autopct=lambda p: '{:.2f}%'.format(round(p,2)) if p > 3. else '',textprops={'fontsize': 25})
title_text = "חניוני תל אביב ללא גוש דן"
plt.title(f'{all_data.columns[16][45::-1]} :{title_text[::-1]}', size=  30)
plt.xticks(rotation = 90,size = 16)
plt.yticks(size = 14)
plt.legend(labels,loc = 'upper left',fontsize = 14)
plt.show()
